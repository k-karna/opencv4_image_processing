# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt

# %%
def show_img_with_plt(color_img, title):
    """Shows an image using matplotlib capabilities"""

    # Convert BGR image to RGB
    img_RGB = color_img[:, :, ::-1]

    plt.imshow(img_RGB)
    plt.title(title)
    plt.axis('off')


def show_hist_plt_gray(hist, title, color):
    """Shows the histogram using matplotlib capabilities"""

    plt.title(title)
    plt.xlabel("bins")
    plt.ylabel("number of pixels")
    plt.xlim([0, 256])
    plt.plot(hist, color=color)


# Create the dimensions of the figure and set title:
plt.figure(figsize=(14, 10))
plt.suptitle("Grayscale histograms introduction", fontsize=14, fontweight='bold')
# Out:
# Text(0.5, 0.98, 'Grayscale histograms introduction')

# %%
def build_sample_image():
    """ 
    Build a sample image with 50x50 regions of different tones
    """

    tones = np.arange(start=60, stop=240, step=30)

    #Initialize result with the first 50x50 region with
    #30-intensity level
    result = np.ones((50, 50, 3), dtype="uint8") * 30

    #build the image concatenating horizontally the regions

    for tone in tones:
        img = np.ones((50, 50, 3), dtype="uint8") * tone
        result = np.concatenate((result, img), axis=1)
    return result

# %%
image = build_sample_image()
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
show_img_with_plt(cv2.cvtColor(gray_image, cv2.COLOR_GRAY2BGR), "Image with 50x50 regions of different GREY")

# %%
hist = cv2.calcHist([gray_image], [0], None, [256], [0, 256])
show_hist_plt_gray(hist, "grayscale histogram", 'm')

# %%
def build_sample_image2():

    """ 
    Builds a sample image with 50x50 regions of different tones
    flipping the output of build_sample_image()

    """

    img = np.fliplr(build_sample_image())
    return img

# %%
# Load the second image and convert it to grayscale:
image_2 = build_sample_image2()
gray_image_2 = cv2.cvtColor(image_2, cv2.COLOR_BGR2GRAY)

# %%
show_img_with_plt(cv2.cvtColor(gray_image_2, cv2.COLOR_GRAY2BGR),
                         "image with 50x50 regions of different tones of gray")

# %%
hist_2 = cv2.calcHist([gray_image_2], [0], None, [256], [0, 256])
show_hist_plt_gray(hist_2, "grayscale histogram", 'm')
